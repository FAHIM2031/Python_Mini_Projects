# %%
print("hello")
# Out:
# hello

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[10,20,15,25]
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
x=['mon','tues','wednes','thurs','friday']
y=[10,20,15,25,30]
plt.plot(x,y)
plt.title("Bakery of the year")
plt.xlabel("Days of the week")
plt.ylabel("Sales per day")
plt.show()
